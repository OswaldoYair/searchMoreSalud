# %%
import pandas as pd
import numpy as np
df = pd.read_csv('tlacuaches.csv')
df
# Out:
#      case  site    Pop sex  age  hdlngth  skullw  totlngth  taill  footlgth
# 0       1     1    Vic   m    8     94.1    60.4      89.0   36.0      74.5  \
# 1       2     1    Vic   f    6     92.5    57.6      91.5   36.5      72.5
# 2       3     1    Vic   f    6     94.0    60.0      95.5   39.0      75.4
# 3       4     1    Vic   f    6     93.2    57.1      92.0   38.0      76.1
# 4       5     1    Vic   f    2     91.5    56.3      85.5   36.0      71.0
# ..    ...   ...    ...  ..  ...      ...     ...       ...    ...       ...
# 99    100     7  other   m    1     89.5    56.0      81.5   36.5      66.0
# 100   101     7  other   m    1     88.6    54.7      82.5   39.0      64.4
# 101   102     7  other   f    6     92.4    55.0      89.0   38.0      63.5
# 102   103     7  other   m    4     91.5    55.2      82.5   36.5      62.9
# 103   104     7  other   f    3     93.6    59.9      89.0   40.0      67.6
#
#      earconch   eye  chest  belly
# ...

# %%
#Selecciono mis datos para el entrenamiento del sistema
train = df.iloc[:90,:]
train
# Out:
#     case  site    Pop sex  age  hdlngth  skullw  totlngth  taill  footlgth
# 0      1     1    Vic   m    8     94.1    60.4      89.0   36.0      74.5  \
# 1      2     1    Vic   f    6     92.5    57.6      91.5   36.5      72.5
# 2      3     1    Vic   f    6     94.0    60.0      95.5   39.0      75.4
# 3      4     1    Vic   f    6     93.2    57.1      92.0   38.0      76.1
# 4      5     1    Vic   f    2     91.5    56.3      85.5   36.0      71.0
# ..   ...   ...    ...  ..  ...      ...     ...       ...    ...       ...
# 85    86     6  other   f    3     88.2    53.2      86.5   38.5      60.3
# 86    87     7  other   m    2     98.5    60.7      93.0   41.5      71.7
# 87    88     7  other   f    2     89.6    58.0      87.5   38.0      66.7
# 88    89     7  other   m    6     97.7    58.4      84.5   35.0      64.4
# 89    90     7  other   m    3     92.6    54.6      85.0   38.5      69.8
#
#     earconch   eye  chest  belly
# 0       54.5  15.2   28.0   36.0
# ...

# %%
x_train = train.iloc[:,[5,6,7,8,9]]
x_train
# Out:
#     hdlngth  skullw  totlngth  taill  footlgth
# 0      94.1    60.4      89.0   36.0      74.5
# 1      92.5    57.6      91.5   36.5      72.5
# 2      94.0    60.0      95.5   39.0      75.4
# 3      93.2    57.1      92.0   38.0      76.1
# 4      91.5    56.3      85.5   36.0      71.0
# ..      ...     ...       ...    ...       ...
# 85     88.2    53.2      86.5   38.5      60.3
# 86     98.5    60.7      93.0   41.5      71.7
# 87     89.6    58.0      87.5   38.0      66.7
# 88     97.7    58.4      84.5   35.0      64.4
# 89     92.6    54.6      85.0   38.5      69.8
#
# [90 rows x 5 columns]

# %%
y_train = train.iloc[:,3]
y_train
# Out:
# 0     m
# 1     f
# 2     f
# 3     f
# 4     f
#      ..
# 85    f
# 86    m
# 87    f
# 88    m
# 89    m
# Name: sex, Length: 90, dtype: object

# %%
#Luego se agarro los datos sobrantes para realizar un seccion o conjunto de testeo
test = df.iloc[90:,:]
test
# Out:
#      case  site    Pop sex  age  hdlngth  skullw  totlngth  taill  footlgth
# 90     91     7  other   m    3     97.8    59.6      89.0   38.0      65.5  \
# 91     92     7  other   m    2     90.7    56.3      85.0   37.0      67.6
# 92     93     7  other   m    3     89.2    54.0      82.0   38.0      63.8
# 93     94     7  other   m    7     91.8    57.6      84.0   35.5      64.2
# 94     95     7  other   m    4     91.6    56.6      88.5   37.5      64.5
# 95     96     7  other   m    4     94.8    55.7      83.0   38.0      66.5
# 96     97     7  other   m    3     91.0    53.1      86.0   38.0      63.8
# 97     98     7  other   m    5     93.2    68.6      84.0   35.0      65.6
# 98     99     7  other   f    3     93.3    56.2      86.5   38.5      64.8
# 99    100     7  other   m    1     89.5    56.0      81.5   36.5      66.0
# 100   101     7  other   m    1     88.6    54.7      82.5   39.0      64.4
# ...

# %%
x_test = test.iloc[:,[5,6,7,8,9]]
x_test
# Out:
#      hdlngth  skullw  totlngth  taill  footlgth
# 90      97.8    59.6      89.0   38.0      65.5
# 91      90.7    56.3      85.0   37.0      67.6
# 92      89.2    54.0      82.0   38.0      63.8
# 93      91.8    57.6      84.0   35.5      64.2
# 94      91.6    56.6      88.5   37.5      64.5
# 95      94.8    55.7      83.0   38.0      66.5
# 96      91.0    53.1      86.0   38.0      63.8
# 97      93.2    68.6      84.0   35.0      65.6
# 98      93.3    56.2      86.5   38.5      64.8
# 99      89.5    56.0      81.5   36.5      66.0
# 100     88.6    54.7      82.5   39.0      64.4
# 101     92.4    55.0      89.0   38.0      63.5
# 102     91.5    55.2      82.5   36.5      62.9
# 103     93.6    59.9      89.0   40.0      67.6

# %%
y_test = test.iloc[:,3]
y_test
# Out:
# 90     m
# 91     m
# 92     m
# 93     m
# 94     m
# 95     m
# 96     m
# 97     m
# 98     f
# 99     m
# 100    m
# 101    f
# 102    m
# 103    f
# Name: sex, dtype: object

# %%
#Se agrega la libreria de "Sklearn" 
from sklearn.svm import SVC
modelo = SVC(kernel='rbf', gamma=0.1, C=1)
modelo.fit(x_train, y_train)
# Out:
# SVC(C=1, gamma=0.1)

# %%
#En esta seccion, mando a realizar la precion con la seccion agarrada de testeo
predicted = modelo.predict(x_test)
predicted
# Out:
# array(['m', 'm', 'm', 'm', 'f', 'm', 'f', 'm', 'm', 'm', 'm', 'f', 'm',
#        'm'], dtype=object)

# %%
test = pd.DataFrame(test)
test['Prediccion del sexo del tlacuache'] = predicted
test
# Out:
#      case  site    Pop sex  age  hdlngth  skullw  totlngth  taill  footlgth
# 90     91     7  other   m    3     97.8    59.6      89.0   38.0      65.5  \
# 91     92     7  other   m    2     90.7    56.3      85.0   37.0      67.6
# 92     93     7  other   m    3     89.2    54.0      82.0   38.0      63.8
# 93     94     7  other   m    7     91.8    57.6      84.0   35.5      64.2
# 94     95     7  other   m    4     91.6    56.6      88.5   37.5      64.5
# 95     96     7  other   m    4     94.8    55.7      83.0   38.0      66.5
# 96     97     7  other   m    3     91.0    53.1      86.0   38.0      63.8
# 97     98     7  other   m    5     93.2    68.6      84.0   35.0      65.6
# 98     99     7  other   f    3     93.3    56.2      86.5   38.5      64.8
# 99    100     7  other   m    1     89.5    56.0      81.5   36.5      66.0
# 100   101     7  other   m    1     88.6    54.7      82.5   39.0      64.4
# ...

# %%
#Seccion para visualizar la presicion de las predicciones
from sklearn.model_selection import cross_val_score
from sklearn.neighbors import KNeighborsClassifier
modeloNeigh = KNeighborsClassifier(n_neighbors=5)

#Yo escogui que solo se sacara la precision de 5 predicciones y el resultado es el mostrado en la impresion
scores = cross_val_score(modeloNeigh, x_train, y_train.values.ravel(), cv=5, scoring='accuracy')
print("Accuracy en cada interacion: ", scores)
# Out:
# Accuracy en cada interacion:  [0.61111111 0.55555556 0.5        0.66666667 0.61111111]

# %%
#Esta seccion es para mostrar la precision general o promedio
accuracy_promedio = np.mean(scores)
print("El accuracy promedio es de: ", accuracy_promedio)
# Out:
# El accuracy promedio es de:  0.5888888888888889
